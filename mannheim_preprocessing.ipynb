# %%
import pandas as pd

# %%
DATA_PATH_SUB = []
for i in range(1, 8):
    DATA_PATH_SUB.append("./dailylog2016_dataset/subject" + str(i) + "/data/")

# %%
subject1_activity_df = pd.read_csv(DATA_PATH_SUB[0] + "activity.csv")

# %%
subject1_activity_df.head(20)
# Out:
#     id  dayID  subjectID     attr_starttime       attr_endtime  \
# 0    1      1          5  11.03.15 08:06:34  11.03.15 08:07:44
# 1    2      1          5  11.03.15 08:08:35  11.03.15 08:24:19
# 2    3      1          5  11.03.15 08:24:59  11.03.15 08:25:44
# 3    4      1          5  11.03.15 08:26:36  11.03.15 10:03:22
# 4    5      1          5  11.03.15 10:07:47  11.03.15 10:33:48
# 5    6      1          5  11.03.15 10:38:02  11.03.15 10:47:55
# 6    7      1          5  11.03.15 10:43:33  11.03.15 10:48:49
# 7    8      1          5  11.03.15 10:55:16  11.03.15 11:21:15
# 8    9      1          5  11.03.15 11:21:52  11.03.15 11:24:02
# 9   10      1          5  11.03.15 11:24:35  11.03.15 11:56:01
# 10  11      1          5  11.03.15 11:35:11  11.03.15 11:56:38
# 11  12      1          5  11.03.15 11:59:31  11.03.15 13:30:58
# 12  13      1          5  11.03.15 13:46:02  11.03.15 14:05:16
# 13  14      1          5  11.03.15 14:12:48  11.03.15 14:14:39
# ...

# %%
subject1_activity_df.subjectID.unique()
# Out:
# array([5])

# %%
subject1_gps_df = pd.read_csv(DATA_PATH_SUB[0] + "gps_csv/SensorGPSData_labeled_day1.csv")

# %%
subject1_gps_df.head(20)
# Out:
#     id              attr_time   attr_lat  attr_lng    label_environment  \
# 0    1  11.03.15 07:58:57.836  49.485568  8.456165              unknown
# 1    2  11.03.15 08:01:58.835  49.486088  8.455536  Street/Road/Pasture
# 2    3  11.03.15 08:02:33.836  49.486586  8.455479  Street/Road/Pasture
# 3    4  11.03.15 08:03:06.836  49.487090  8.455752  Street/Road/Pasture
# 4    5  11.03.15 10:09:55.835  49.487586  8.457593  Street/Road/Pasture
# 5    6  11.03.15 13:34:07.035  49.487088  8.457737  Street/Road/Pasture
# 6    7  11.03.15 13:35:20.835  49.486591  8.458993  Street/Road/Pasture
# 7    8  11.03.15 13:36:15.835  49.486083  8.459373  Street/Road/Pasture
# 8    9  11.03.15 13:36:49.836  49.485583  8.459374  Street/Road/Pasture
# 9   10  11.03.15 13:38:17.835  49.485081  8.459907  Street/Road/Pasture
# 10  11  11.03.15 13:39:03.836  49.484583  8.459770  Street/Road/Pasture
# 11  12  11.03.15 14:08:11.036  49.485083  8.459623  Street/Road/Pasture
# ...

# %%
subject4_gps_df = pd.read_csv(DATA_PATH_SUB[3] + "gps_csv/SensorGPSData_labeled_day1.csv")

# %%
subject4_gps_df.head()
# Out:
#    id              attr_time   attr_lat  attr_lng label_environment  \
# 0   1  10.03.15 11:27:22.614  49.487179  8.458814              Büro
# 1   2  10.03.15 15:34:51.643  49.488630  8.462544           Zuhause
# 2   3  10.03.15 15:34:58.643  49.488131  8.462008           Zuhause
# 3   4  10.03.15 18:15:47.476  49.488726  8.462420  Straße/Weg/Wiese
# 4   5  10.03.15 18:16:24.482  49.488229  8.462546  Straße/Weg/Wiese
#
#   label_posture label_deviceposition      label_activity  label_valid
# 0        sitzen         Oberschenkel  Schreibtischarbeit         True
# 1        sitzen         Oberschenkel  Schreibtischarbeit         True
# 2        sitzen         Oberschenkel  Schreibtischarbeit         True
# 3         gehen         Oberschenkel         Fortbewegen         True
# 4         gehen         Oberschenkel         Fortbewegen         True

# %%
subject1_gps_df.label_activity.unique()
# Out:
# array(['unknown', 'Socializing', 'Desk Work', 'Movement',
#        'Personal Grooming'], dtype=object)
